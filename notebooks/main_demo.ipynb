# %%
# Step 1: Import necessary modules
import torch
from src.model import SimpleNN
from src.data_utils import load_data

# Step 2: Load and prepare the data
X_train, X_test, y_train, y_test = load_data()
print("Data loaded successfully!")
print(f"Training samples: {X_train.shape[0]}, Test samples: {X_test.shape[0]}")

# Step 3: Define the model
input_size = X_train.shape[1]  # number of features
hidden_size = 16
output_size = 2  # number of classes
model = SimpleNN(input_size, hidden_size, output_size)
print("Model created successfully!")

# Step 4: Define loss and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# Step 5: Training loop
epochs = 20
for epoch in range(epochs):
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs, y_train)
    loss.backward()
    optimizer.step()
    print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.item():.4f}")

# Step 6: Evaluate the model
with torch.no_grad():
    predictions = model(X_test).argmax(dim=1)
    accuracy = (predictions == y_test).float().mean()
    print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import torch
#       3 from src.model import SimpleNN
# ----> 4 from src.data_utils import load_data
#       6 # Step 2: Load and prepare the data
#       7 X_train, X_test, y_train, y_test = load_data()
#
# File ~\Documents\MyProject\notebooks\src\data_utils.py:2
#       1 import torch
# ----> 2 from sklearn.datasets import make_classification
#       3 from sklearn.model_selection import train_test_split
#       4 from sklearn.preprocessing import StandardScaler
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# Step 1: Import necessary modules
import torch
from src.model import SimpleNN
from src.data_utils import load_data

# Step 2: Load and prepare the data
X_train, X_test, y_train, y_test = load_data()
print("Data loaded successfully!")
print(f"Training samples: {X_train.shape[0]}, Test samples: {X_test.shape[0]}")

# Step 3: Define the model
input_size = X_train.shape[1]  # number of features
hidden_size = 16
output_size = 2  # number of classes
model = SimpleNN(input_size, hidden_size, output_size)
print("Model created successfully!")

# Step 4: Define loss and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# Step 5: Training loop
epochs = 20
for epoch in range(epochs):
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs, y_train)
    loss.backward()
    optimizer.step()
    print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.item():.4f}")

# Step 6: Evaluate the model
with torch.no_grad():
    predictions = model(X_test).argmax(dim=1)
    accuracy = (predictions == y_test).float().mean()
    print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Data loaded successfully!
# Training samples: 400, Test samples: 100
# Model created successfully!
# Epoch 1/20, Loss: 0.7972
# Epoch 2/20, Loss: 0.7629
# Epoch 3/20, Loss: 0.7332
# Epoch 4/20, Loss: 0.7073
# Epoch 5/20, Loss: 0.6840
# Epoch 6/20, Loss: 0.6627
# Epoch 7/20, Loss: 0.6431
# Epoch 8/20, Loss: 0.6244
# Epoch 9/20, Loss: 0.6062
# Epoch 10/20, Loss: 0.5881
# Epoch 11/20, Loss: 0.5699
# Epoch 12/20, Loss: 0.5514
# Epoch 13/20, Loss: 0.5327
# Epoch 14/20, Loss: 0.5138
# Epoch 15/20, Loss: 0.4947
# Epoch 16/20, Loss: 0.4753
# Epoch 17/20, Loss: 0.4561
# Epoch 18/20, Loss: 0.4367
# Epoch 19/20, Loss: 0.4177
# Epoch 20/20, Loss: 0.3991
# Test Accuracy: 0.8700

# %%
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
print(X_train[:5])  # Preview first 5 samples
print(y_train[:5])
# Out:
# torch.Size([400, 10]) torch.Size([100, 10])
# torch.Size([400]) torch.Size([100])
# tensor([[ 0.5625, -0.4826,  0.1344, -0.4187, -0.0535,  0.0694, -0.4109,  0.0888,
#          -0.6142,  0.0949],
#         [-1.4385,  1.4559,  2.6638, -0.1038,  0.3972, -1.7972, -1.2460, -0.5046,
#          -0.5118,  0.3001],
#         [ 0.9006,  0.5144,  2.2908, -0.0960, -1.4434,  0.3360,  1.0799,  0.4878,
#           1.2655,  0.6204],
#         [-1.3433,  0.7532,  0.0344,  0.6158,  0.1133, -0.1395,  0.5925, -0.5277,
#           0.9122, -0.9402],
#         [-1.1660, -0.9671, -0.1272,  0.6546, -0.9940,  0.0679, -0.9350,  1.2590,
#          -1.3370, -0.1633]])
# tensor([0, 1, 1, 1, 0])

# %%
import torch
import numpy as np
from src.model import SimpleNN
from src.data_utils import load_data

# %%
X_train, X_test, y_train, y_test = load_data()
print(X_train.shape, y_train.shape)
# Out:
# torch.Size([400, 10]) torch.Size([400])

# %%
model = SimpleNN(input_dim=X_train.shape[1], hidden_dim=32, output_dim=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model = SimpleNN(input_dim=X_train.shape[1], hidden_dim=32, output_dim=2)
#
# TypeError: SimpleNN.__init__() got an unexpected keyword argument 'input_dim'. Did you mean 'input_size'?

# %%
model = SimpleNN(input_size=X_train.shape[1], hidden_dim=32, output_dim=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model = SimpleNN(input_size=X_train.shape[1], hidden_dim=32, output_dim=2)
#
# TypeError: SimpleNN.__init__() got an unexpected keyword argument 'hidden_dim'. Did you mean 'hidden_size'?

# %%
model = SimpleNN(input_size=X_train.shape[1], hidden_size=32, output_dim=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model = SimpleNN(input_size=X_train.shape[1], hidden_size=32, output_dim=2)
#
# TypeError: SimpleNN.__init__() got an unexpected keyword argument 'output_dim'. Did you mean 'output_size'?

# %%
model = SimpleNN(input_size=X_train.shape[1], hidden_size=32, output_size=2)

# %%
import torch.nn as nn
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)
# Out:
# C:\Users\KAMALESH\AppData\Local\Temp\ipykernel_9680\1658713426.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
# C:\Users\KAMALESH\AppData\Local\Temp\ipykernel_9680\1658713426.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train_tensor = torch.tensor(y_train, dtype=torch.long)
# C:\Users\KAMALESH\AppData\Local\Temp\ipykernel_9680\1658713426.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
# ...

# %%
X_train_tensor = X_train.clone().detach().float()
y_train_tensor = y_train.clone().detach().long()
X_test_tensor  = X_test.clone().detach().float()
y_test_tensor  = y_test.clone().detach().long()

# %%
import torch.nn as nn
import torch.optim as optim

# Loss function for classification
criterion = nn.CrossEntropyLoss()

# Optimizer (Adam is common)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Number of epochs
epochs = 50

for epoch in range(epochs):
    # Set model to training mode
    model.train()
    
    # Forward pass
    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)
    
    # Backward pass
    optimizer.zero_grad()  # clear previous gradients
    loss.backward()        # compute gradients
    optimizer.step()       # update weights
    
    if (epoch+1) % 10 == 0:
        print(f"Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}")
# Out:
# Epoch [10/50], Loss: 0.6572
# Epoch [20/50], Loss: 0.6161
# Epoch [30/50], Loss: 0.5780
# Epoch [40/50], Loss: 0.5406
# Epoch [50/50], Loss: 0.5030

# %%
# Set model to evaluation mode
model.eval()

# Forward pass on test data
with torch.no_grad():  # no gradients needed for evaluation
    test_outputs = model(X_test_tensor)
    _, predicted = torch.max(test_outputs, 1)  # get class with highest score
    accuracy = (predicted == y_test_tensor).sum().item() / y_test_tensor.size(0)

print(f"Test Accuracy: {accuracy*100:.2f}%")
# Out:
# Test Accuracy: 86.00%

# %%
# -------------------------------
# Step 6: Save Model and Visualize Results
# -------------------------------

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Save the trained model
model_path = "../src/simple_nn_model.pth"
torch.save(model.state_dict(), model_path)
print(f"Model saved at: {model_path}")

# -------------------------------
# Visualize predictions on test set
# -------------------------------
model.eval()  # Set model to evaluation mode
with torch.no_grad():
    y_pred = model(X_test_tensor)
    y_pred_classes = torch.argmax(y_pred, dim=1)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix: Test Set")
plt.show()

# Optional: Calculate accuracy
accuracy = (y_pred_classes == y_test_tensor).float().mean()
print(f"Test Accuracy (recalculated): {accuracy*100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       8 # Save the trained model
#       9 model_path = "../src/simple_nn_model.pth"
# ---> 10 torch.save(model.state_dict(), model_path)
#      11 print(f"Model saved at: {model_path}")
#      13 # -------------------------------
#      14 # Visualize predictions on test set
#      15 # -------------------------------
#
# NameError: name 'torch' is not defined

# %%
# -------------------------------
# Step 0: Import required libraries
# -------------------------------
import torch
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from src.model import SimpleNN
from src.data_utils import load_data

# -------------------------------
# Step 1: Load data
# -------------------------------
X_train, X_test, y_train, y_test = load_data()

# Convert to tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# -------------------------------
# Step 2: Load model
# -------------------------------
input_size = X_train.shape[1]
hidden_size = 32
output_size = 2

model = SimpleNN(input_size=input_size, hidden_size=hidden_size, output_size=output_size)

# If you have a previously saved model, load it:
# model.load_state_dict(torch.load("../src/simple_nn_model.pth"))

# -------------------------------
# Step 3: Evaluate model
# -------------------------------
model.eval()
with torch.no_grad():
    y_pred = model(X_test_tensor)
    y_pred_classes = torch.argmax(y_pred, dim=1)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix: Test Set")
plt.show()

# Test accuracy
accuracy = (y_pred_classes == y_test_tensor).float().mean()
print(f"Test Accuracy: {accuracy*100:.2f}%")

# -------------------------------
# Step 4: Save model
# -------------------------------
model
# Out:
# C:\Users\KAMALESH\AppData\Local\Temp\ipykernel_17028\1404165204.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
# C:\Users\KAMALESH\AppData\Local\Temp\ipykernel_17028\1404165204.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train_tensor = torch.tensor(y_train, dtype=torch.long)
# C:\Users\KAMALESH\AppData\Local\Temp\ipykernel_17028\1404165204.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
# ...

# %%
import torch

# Save model weights
torch.save(model.state_dict(), "../src/simple_nn_model.pth")
print("Model saved successfully at src/simple_nn_model.pth")
# Out:
# Model saved successfully at src/simple_nn_model.pth

# %%
from src.model import SimpleNN

# Initialize the model structure
loaded_model = SimpleNN(input_size=10, hidden_size=32, output_size=2)
# Load the trained weights
loaded_model.load_state_dict(torch.load("../src/simple_nn_model.pth"))
loaded_model.eval()  # Set to evaluation mode
# Out:
# SimpleNN(
#   (fc1): Linear(in_features=10, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=2, bias=True)
# )

# %%
with torch.no_grad():
    # X_test is already a tensor, so no need to copy or convert
    sample_data = X_test[:5]
    predictions = loaded_model(sample_data)
    predicted_classes = torch.argmax(predictions, dim=1)
    
print("Predicted classes:", predicted_classes)
# Out:
# Predicted classes: tensor([1, 1, 1, 1, 1])
